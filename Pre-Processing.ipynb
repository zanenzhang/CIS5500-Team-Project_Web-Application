# %%
prefix = '/content/drive'
from google.colab import drive
drive.mount(prefix, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
filepath = '/content/drive/MyDrive/archive (5)/BR_youtube_trending_data.csv'
BR = pd.read_csv(filepath)
## this works 
BR['trending_date'] = BR['trending_date'].str[:10]
BR['publishedAt'] = BR['publishedAt'].str[:10]
BR['country'] = "Brazil"
BR.to_csv("BR2.csv", index=False)
from google.colab import files
files.download('BR2.csv') 
BR.head()
# Out:
#       video_id                                              title publishedAt  \
# 0  s9FH4rDMvds     LEVEI UM FORA? FINGI ESTAR APAIXONADO POR ELA!  2020-08-11
# 1  jbGRowa5tIk                          ITZY “Not Shy” M/V TEASER  2020-08-11
# 2  3EfkCrXKZNs                      Oh Juliana PARÓDIA - MC Niack  2020-08-10
# 3  gBjox7vn3-g   Contos de Runeterra: Targon | A Estrada Tortuosa  2020-08-11
# 4  npoUGx7UW7o  Entrevista com Thammy Miranda | The Noite (10/...  2020-08-11
#
#                   channelId                  channelTitle  categoryId  \
# 0  UCGfBwrCoi9ZJjKiUK8MmJNw                 Pietro Guedes          22
# 1  UCaO6TYtlC8U5ttz62hTrZgg             JYP Entertainment          10
# 2  UCoXZmVma073v5G1cW82UKkA                 As Irmãs Mota          22
# 3  UC6Xqz2pm50gDCORYztqhDpg          League of Legends BR          20
# 4  UCEWOoncsrmirqnFqxer9lmA  The Noite com Danilo Gentili          23
#
#   trending_date                                               tags  \
# ...

# %%
## does not work 
string = BR['trending_date']
BR['trending_date'] = string[0:10]
BR.head()
# Out:
#       video_id                                              title  \
# 0  s9FH4rDMvds     LEVEI UM FORA? FINGI ESTAR APAIXONADO POR ELA!
# 1  jbGRowa5tIk                          ITZY “Not Shy” M/V TEASER
# 2  3EfkCrXKZNs                      Oh Juliana PARÓDIA - MC Niack
# 3  gBjox7vn3-g   Contos de Runeterra: Targon | A Estrada Tortuosa
# 4  npoUGx7UW7o  Entrevista com Thammy Miranda | The Noite (10/...
#
#             publishedAt                 channelId  \
# 0  2020-08-11T22:21:49Z  UCGfBwrCoi9ZJjKiUK8MmJNw
# 1  2020-08-11T15:00:13Z  UCaO6TYtlC8U5ttz62hTrZgg
# 2  2020-08-10T14:59:00Z  UCoXZmVma073v5G1cW82UKkA
# 3  2020-08-11T15:00:09Z  UC6Xqz2pm50gDCORYztqhDpg
# 4  2020-08-11T20:04:02Z  UCEWOoncsrmirqnFqxer9lmA
#
#                    channelTitle  categoryId         trending_date  \
# 0                 Pietro Guedes          22  2020-08-12T00:00:00Z
# 1             JYP Entertainment          10  2020-08-12T00:00:00Z
# ...

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/archive (5)/JP_youtube_trending_data.csv'
JP = pd.read_csv(filepath)
## this works 
JP['trending_date'] = JP['trending_date'].str[:10]
JP['publishedAt'] = JP['publishedAt'].str[:10]
JP['country'] = "Japan"
JP.head()
JP.to_csv("JP2.csv", index=False)
from google.colab import files
files.download('JP2.csv')
# Out:
#       video_id                                              title publishedAt  \
# 0  UYXa8R9vvzA                    皆からの色々な質問に何も隠さず答える！びっくりさせたらごめん笑  2020-08-11
# 1  02MaoZ5n-uM                    【異次元】世界に伝えたい『This is ギータ』【変態打ち】  2020-08-11
# 2  ucDDYszgj5c                【親心】てつやを一番よく知るのは誰？第１回てつやの母親に聞くてつや王！  2020-08-11
# 3  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...  2020-08-11
# 4  tkaU_Ctzhes                  映画『銀魂 THE FINAL』特報　2021年1月8日(金)公開  2020-08-11
#
#                   channelId                     channelTitle  categoryId  \
# 0  UCZCzstgLGQdK8GSztJHh0-w                             タナカガ          22
# 1  UC0v-pxTo1XamIDE-f__Ad0Q  (パーソル パ・リーグTV公式)PacificLeagueTV          17
# 2  UCutJqz56653xV2wwSvut_hQ                           東海オンエア          23
# 3  UC0ZV6M2THA81QT9hrVWJG3A                     Apex Legends          20
# 4  UCSrwpEM8lBM4jR5YoKX3XOQ               ワーナー ブラザース 公式チャンネル           1
#
# ...

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/archive (5)/US_youtube_trending_data.csv'
US = pd.read_csv(filepath)
## this works 
US['trending_date'] = US['trending_date'].str[:10]
US['publishedAt'] = US['publishedAt'].str[:10]
US['country'] = "United States"
US.head()
US.to_csv("US.csv", index=False)
from google.colab import files
files.download('US.csv')

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/archive (5)/CA_youtube_trending_data.csv'
CA = pd.read_csv(filepath)
## this works 
CA['trending_date'] = CA['trending_date'].str[:10]
CA['publishedAt'] = CA['publishedAt'].str[:10]
CA['country'] = "Canada"
CA.head()
CA.to_csv("CA.csv", index=False)
from google.colab import files
files.download('CA.csv')

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/archive (5)/DE_youtube_trending_data.csv'
DE = pd.read_csv(filepath)
## this works 
DE['trending_date'] = DE['trending_date'].str[:10]
DE['publishedAt'] = DE['publishedAt'].str[:10]
DE['country'] = "Germany"
DE.head()
DE.to_csv("DE1.csv", index=False)
from google.colab import files
files.download('DE1.csv')

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/archive (5)/FR_youtube_trending_data.csv'
FR = pd.read_csv(filepath)
## this works 
FR['trending_date'] = FR['trending_date'].str[:10]
FR['publishedAt'] = FR['publishedAt'].str[:10]
FR['country'] = "France"
FR.head()
FR.to_csv("FR.csv", index=False)
from google.colab import files
files.download('FR.csv')

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/archive (5)/GB_youtube_trending_data.csv'
GB = pd.read_csv(filepath)
## this works 
GB['trending_date'] = GB['trending_date'].str[:10]
GB['publishedAt'] = GB['publishedAt'].str[:10]
GB['country'] = "United Kingdom"
GB.head()
GB.to_csv("GB.csv", index=False)
from google.colab import files
files.download('GB.csv')

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/archive (5)/IN_youtube_trending_data.csv'
IN = pd.read_csv(filepath)
## this works 
IN['trending_date'] = IN['trending_date'].str[:10]
IN['publishedAt'] = IN['publishedAt'].str[:10]
IN['country'] = "India"
IN.head()
IN.to_csv("IN.csv", index=False)
from google.colab import files
files.download('IN.csv')

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/archive (5)/KR_youtube_trending_data.csv'
KR = pd.read_csv(filepath)
## this works 
KR['trending_date'] = KR['trending_date'].str[:10]
KR['publishedAt'] = KR['publishedAt'].str[:10]
KR['country'] = "South Korea"
KR.head()
KR.to_csv("KR.csv", index=False)
from google.colab import files
files.download('KR.csv')

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/archive (5)/MX_youtube_trending_data.csv'
MX = pd.read_csv(filepath)
## this works 
MX['trending_date'] = MX['trending_date'].str[:10]
MX['publishedAt'] = MX['publishedAt'].str[:10]
MX['country'] = "Mexico"
MX.head()
MX.to_csv("MX.csv", index=False)
from google.colab import files
files.download('MX.csv')

# %%
import pandas as pd
filepath = '/content/drive/MyDrive/archive (5)/RU_youtube_trending_data.csv'
RU = pd.read_csv(filepath)
## this works 
RU['trending_date'] = RU['trending_date'].str[:10]
RU['publishedAt'] = RU['publishedAt'].str[:10]
RU['country'] = "Russia"
RU.head()
RU.to_csv("RU.csv", index=False)
from google.colab import files
files.download('RU.csv')
